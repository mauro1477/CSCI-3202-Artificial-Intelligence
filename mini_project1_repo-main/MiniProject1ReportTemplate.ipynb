# %% [markdown]
# # Mini Project 1 Report

# %% [markdown]
# Your name: `Mauro Vargas`

# %%
# %matplotlib inline
import math 
import time
from curveFitting import one_dimensional_curve_fitting_test

# %% [markdown]
# ## Benchmarking

# %% [markdown]
# - Attempt these problems only after you have finished and tested your implementation.
# - If you modify any of the python files, remember to "restart the kernel" or else the changes will not take effect.
# - We have provided 5 tests below. For each test, run it 5 different times and record the best solution/fitness for each trial along with the run time.
# - You will need to modify the code below, perhaps adding some nice print statements or adding your results to a table.

# %%
one_dimensional_curve_fitting_test(lambda x: 0.2*math.exp(x/4.0) -  math.sin(2*x)  , (-10.0, 10.0), 25)
# start_time = time.time()
# print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# GA Returned Solution: (cos((x + x + 2.0)) + 0.5) with fitness -10.551280576414275

# %%
one_dimensional_curve_fitting_test(lambda x: math.sin(2*x) - math.cos(3*x-1) + 2*math.sin(x/2+1.0)  , (-15.0, 15.0), 60)
# start_time = time.time()
# print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# GA Returned Solution: (sin(((x/2.0) + 0.8775825618903728))/cos(sin((x * 2.0)))) with fitness -59.2150728340988

# %%
one_dimensional_curve_fitting_test(lambda x: math.exp(math.sin(2*x)) - math.exp(math.cos(3*x))  , (-15.0, 15.0), 60)
# start_time = time.time()
# print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# GA Returned Solution: cos(((x + -0.5) + x + -1.0) - cos(x)) with fitness -34.48808169574548

# %%
one_dimensional_curve_fitting_test(lambda x: 0.05*x**2 - 0.5*x + 5.0 * math.sin(3*x) , (-15.0, 15.0), 60)
# start_time = time.time()
# print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# GA Returned Solution: sqrt(exp(((x * -0.5)/1.4142135623730951))) with fitness -896.1062596811228

# %%
one_dimensional_curve_fitting_test(lambda x: 0.05*x**2 - 0.5*math.sqrt(x) + 5.0 * math.sin(3*x) , (0.0, 15.0), 30)
# start_time = time.time()
# print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# GA Returned Solution: ((x/2.0) - (0.04510812238487638) + sin((x + x + x))) with fitness -230.24317328188704

# %% [markdown]
# `Put your table with results here!` You may [create a table using markdown](https://www.tablesgenerator.com/markdown_tables) (below) or print a nicely formatted table using a library such as Pandas.
#
# | Tests    | Fitness  |  Seconds |
# |---  |---  |---  |
# |  Test1 | -6.861523888324127  |  4.410743713378906e-05 |
# |  Test1 | -10.653777372445973 |  4.410743713378906e-05 |
# |  Test1 | -7.798970857295198  |  4.315376281738281e-05 |
# |  Test1 | -7.288402517278344  |  4.363059997558594e-05 |
# |  Test1 | -7.288402517278344  |  4.363059997558594e-05 |
# |  Test2 | -80.27034953909101  |  4.291534423828125e-05 |
# |  Test2 | -80.79532600579401  |  4.291534423828125e-05 |
# |  Test2 | -71.55181393606654  |  4.291534423828125e-05 |
# |  Test2 | -68.75560536124702  |  4.57763671875e-05     |
# |  Test2 | -86.17049407667163  |  4.1961669921875e-05   |
# |  Test3 | -32.42261064426602  |  4.291534423828125e-05 |
# |  Test3 | -5.249699795459231  |  4.38690185546875e-05  |
# |  Test3 | -30.03704401282939  |  4.792213439941406e-05 |
# |  Test3 | -6.122001275456207  |  4.410743713378906e-05 |
# |  Test3 | -25.496650237507925 |  4.1961669921875e-05   |
# |  Test4 | -761.2849275221021  |  4.410743713378906e-05 |
# |  Test4 | -724.3772896840753  |  4.291534423828125e-05 |
# |  Test4 | -947.2154613889578  |  4.291534423828125e-05 |
# |  Test4 | -817.4653883940904  |  4.291534423828125e-05 |
# |  Test4 | -1285.1937422869278 |  4.291534423828125e-05 |
# |  Test5 | -252.6403613193038  |  4.458427429199219e-05 |
# |  Test5 | -1285.1937422869278 |  4.291534423828125e-05 |
# |  Test5 | -134.94171223386493 |  4.291534423828125e-05 |
# |  Test5 | -175.16571873632975 |  4.410743713378906e-05 |
# |  Test5 | -384.22459459589754 |  4.1961669921875e-05   |
# |  Test5 | -418.3470772426476  |  4.315376281738281e-05 |

# %% [markdown]
# Write a brief analysis of your results. Some questions to answer:
# - Which problem ran the fastest? Why do you think this is the case?
# - Which problem ended with the highest fitness? Why do you think this is the case?
# - How similar were the running times across the 5 repetitions?
# - How similar were the final fitness scores across the 5 repetitions?
# - Was there anything else interesting in your results?

# %% [markdown]
# `
# Question 1: Test 2, Test 3 and Test 5 ran the same fastest time  4.1961669921875e-05. I think they all ran the same fastest time, because the population was already close to being all sorted.
# Question 2: Test 1 had the hightest fitness score of -6.861523888324127. It got the highest fitness score out of all the other Test because the orginal population had a high fitness score average to begin with.
# Question 3: The spread of the Test fitness score was pretty small
# Question 4: The 5th repetition seemed to always have the worst fitness score out of all the repetitions.
# Question 5: The 2nd and 3rd repetition seemed to have a high proablility of producing the highest fitness score`

# %% [markdown]
# ## Describe Your Implementation and Reflect

# %% [markdown]
# Some questions to answer in your write-up:
# - What was your strategy to solve this problem?
# - How did you structure your `GASolver` class?
# - What other files or methods did you change?
# - What was the most difficult part of the project?
# - What was something surprising you found?
#
# Please provide some elaboration with your answers. When describing your implementation, remember that we have not watched you solve this problem so you will need to give more details than you think is necessary.

# %% [markdown]
# `
# Question 1: I watched a youtube video on generic algorithms and read the write up several times.
# Question 2: I used a list as my data structure and used a tuple [(expr, score)] to hold the expression and score. After storing the expressions and scores, I sorted the expression by their score. Next I got the top k and added them to next generation and preformed cross over and mutation to get the new children. Finally I justed keep track of the best expression and best fittness score through every repetition.
# Question 3: No, I did not change any of the files or methods.
# Question 4: The most difficult part was just starting and understanding the steps of the generic algorithm (appending, sorting and the random fuction).
# Question 5: The theory that this algorithm mimics natural selecting is surpsing.
# `

# %% [markdown]
# ## Going Above and Beyond

# %% [markdown]
# Describe the extra changes you implemented. Give some details, perhaps a short paragraph for each major change.

# %% [markdown]
# `Your answer here.`

# %% [markdown]
# Describe the analysis you did and provide your results in the form of a figure or a table.

# %% [markdown]
# `Your answer here.`

# %% [markdown]
# Reflect on your work for this section. What was interesting, or what did you learn? A short paragraph here is fine.

# %% [markdown]
# `Your answer here.`
